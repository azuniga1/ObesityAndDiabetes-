# %%
# Dependencies
import pandas as pd

# %%
# Store filepath in a variable
obesity2011 = "Resources/2011-Obesity.csv"

# %%
# Read our Data file with the pandas library
# Not every CSV requires an encoding, but be aware this can come up
obesity2011_df = pd.read_csv(obesity2011, encoding="ISO-8859-1")

# %%
# Show just the header
obesity2011_df.head()
# Out:
#         ID  YearStart  YearEnd  Description LocationAbbr LocationDesc  \
# 0    671.0     2011.0   2011.0       2011.0           US     National
# 1   2279.0     2011.0   2011.0       2011.0           AL      Alabama
# 2  21294.0     2011.0   2011.0       2011.0           AK       Alaska
# 3  24644.0     2011.0   2011.0       2011.0           AZ      Arizona
# 4  13264.0     2011.0   2011.0       2011.0           AR     Arkansas
#
#   DataSource                    Class                    Topic  \
# 0      BRFSS  Obesity / Weight Status  Obesity / Weight Status
# 1      BRFSS  Obesity / Weight Status  Obesity / Weight Status
# 2      BRFSS  Obesity / Weight Status  Obesity / Weight Status
# 3      BRFSS  Obesity / Weight Status  Obesity / Weight Status
# 4      BRFSS  Obesity / Weight Status  Obesity / Weight Status
#
#                                             Question  ...  StratificationId2  \
# 0  Percent of adults aged 18 years and older who ...  ...                NaN
# ...

# %%
# Show mulitple specific columns
New_Df = obesity2011_df[['ID', 'YearStart', 'LocationAbbr', 'LocationDesc', 'Question', 'Data_Value', 'GeoLocation_Lat', 
                'GeoLocation_Long',  ]]
New_Df.head()
# Out:
#         ID  YearStart LocationAbbr LocationDesc  \
# 0    671.0     2011.0           US     National
# 1   2279.0     2011.0           AL      Alabama
# 2  21294.0     2011.0           AK       Alaska
# 3  24644.0     2011.0           AZ      Arizona
# 4  13264.0     2011.0           AR     Arkansas
#
#                                             Question  Data_Value  \
# 0  Percent of adults aged 18 years and older who ...        27.4
# 1  Percent of adults aged 18 years and older who ...        32.0
# 2  Percent of adults aged 18 years and older who ...        27.4
# 3  Percent of adults aged 18 years and older who ...        25.1
# 4  Percent of adults aged 18 years and older who ...        30.9
#
#    GeoLocation_Lat  GeoLocation_Long
# 0              NaN               NaN
# 1        32.840571        -86.631861
# 2        64.845080       -147.722059
# 3        34.865970       -111.763811
# 4        34.748650        -92.274491

# %%
New_Df.dtypes
# Out:
# ID                  float64
# YearStart           float64
# LocationAbbr         object
# LocationDesc         object
# Question             object
# Data_Value          float64
# GeoLocation_Lat     float64
# GeoLocation_Long    float64
# dtype: object
